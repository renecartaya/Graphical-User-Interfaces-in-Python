# %%
#############################################################################################################################
#
#                        Buttom Development
#
#############################################################################################################################
############################# Packages loading ###################################

#import serial as ser # require pip install PySerial for Serial communication
from tkinter import *
import tkinter as tk 
import time   #for delay functions

root = Tk()
root.wm_title('Buttons tester')
root.configure(background = '#e0e0e0')
root.iconbitmap('C:/Users/ASUS/Pictures/Logos/generic-logo.ico')
root.resizable(width=False, height=False)
root.geometry("440x660")

mainFrame = Frame(root)
mainFrame.grid()

innerFrame = Frame(mainFrame)
innerFrame.grid()

       ########################### Functions set ###########################

def turn_LED_ON():
    print("button pressed")

        ###########################Buttons Widget###########################

btn_1 = Button(innerFrame, width=438, height =130, font=('arial',18,'bold'), bd=7, command=turn_LED_ON, text="LED ON", borderwidth=0)
img_1 = PhotoImage(file='C:/Users/ASUS/Desktop/GUI_Development/Buttoms_design/Buttom_1.png')
btn_1.config(image=img_1)
btn_1.grid(row=0,column = 0)

btn_2 = Button(innerFrame, width=438, height =130, font=('arial',18,'bold'), bd=7, command=turn_LED_ON, text="LED ON", borderwidth=0)
img_2 = PhotoImage(file='C:/Users/ASUS/Desktop/GUI_Development/Buttoms_design/Buttom_2.png') 
btn_2.config(image=img_2)
btn_2.grid(row=1,column = 0)

btn_3 = Button(innerFrame, width=438, height =130, font=('arial',18,'bold'), bd=7, command=turn_LED_ON, text="LED ON", borderwidth=0)
img_3 = PhotoImage(file='C:/Users/ASUS/Desktop/GUI_Development/Buttoms_design/Buttom_3.png') 
btn_3.config(image=img_3)
btn_3.grid(row=2,column = 0)

btn_4 = Button(innerFrame, width=438, height =130, font=('arial',18,'bold'), bd=7, command=turn_LED_ON, text="LED ON", borderwidth=0)
img_4 = PhotoImage(file='C:/Users/ASUS/Desktop/GUI_Development/Buttoms_design/Buttom_4.png')
btn_4.config(image=img_4)
btn_4.grid(row=3,column = 0)

btn_5 = Button(innerFrame, width=438, height =130, font=('arial',18,'bold'), bd=7, command=turn_LED_ON, text="LED ON", borderwidth=0)
img_5 = PhotoImage(file='C:/Users/ASUS/Desktop/GUI_Development/Buttoms_design/Buttom_6.png')
btn_5.config(image=img_5)
btn_5.grid(row=4,column = 0)

#btn_On = Button(innerFrame, text="LED ON", width=200, height =100, font=('arial',18,'bold'), bd=7, command=turn_LED_ON,relief=RIDGE)
#img = PhotoImage(file='C:/Users/ASUS/Desktop/CTKinter/Images/Buttom_blue.png') # make sure to add "/" not "\"
#btn_On.config(image=img)
#btn_On.grid(row=0,column = 0)
#btn_On.place(x = stop.winfo_x()+stop.winfo_reqwidth() + 20, y = 450)

#root.update();
#reset = tk.Button(root, text = "Reset", font = ('calbiri',12))
#reset.place(x = stop.winfo_x()+stop.winfo_reqwidth() + 20, y = 450)

root.mainloop()
#ser.close() # Close properly the serial communication and avoid the need to turn off/on the microcontroller board or to have to unplug/plug again
# Out:
# button pressed

# %%
###############################################################################################
#
#                                   Test of buttoms distribution
#
###############################################################################################

# Works in connection with the Encoder_firmware_1.ino

from matplotlib.backends.backend_tkagg import FigureCanvasTkAgg
from matplotlib.figure import Figure
import tkinter as tk
import numpy as np
import serial as ser

# ========================= Main windown settings ============================= #

root = tk.Tk()
root.title('Buttoms distribution tester')
root.configure(background = '#e0e0e0')
root.iconbitmap('C:/Users/ASUS/Pictures/Logos/generic-logo.ico')
root.geometry("520x520") # set the window size

# ====================== Serial port configuration =========================== #

    
def plot_start():
    print("Buttom working")


    
# ================== create Plot object on GUI ============================ #
# add figure canvas

# ================================= buttons set ============================================= #

# ============================= First row of Winglets ============================================ #

root.update();
start_btn = tk.Button(root, text = "Start", font = ('calbiri',12),command=plot_start)
start_btn.place(x = 20, y = 470 )

root.update();
stop_btn = tk.Button(root, text = "Stop", font = ('calbiri',12),command=plot_start)
stop_btn.place(x = start_btn.winfo_x()+start_btn.winfo_reqwidth() + 20, y = 470)

root.update();
reset_btn = tk.Button(root, text = "Reset", font = ('calbiri',12),command=plot_start)
reset_btn.place(x = stop_btn.winfo_x()+stop_btn.winfo_reqwidth() + 20, y = 470)

# ============================= Second row of Winglets ============================================ #

root.update();
start_btn = tk.Button(root, text = "Start", font = ('calbiri',12),command=plot_start)
start_btn.place(x = 20, y = 420 )

root.update();
stop_btn = tk.Button(root, text = "Stop", font = ('calbiri',12),command=plot_start)
stop_btn.place(x = start_btn.winfo_x()+start_btn.winfo_reqwidth() + 20, y = 420)

root.update();
reset_btn = tk.Button(root, text = "Reset", font = ('calbiri',12),command=plot_start)
reset_btn.place(x = stop_btn.winfo_x()+stop_btn.winfo_reqwidth() + 20, y = 420)


# ============================= Third row of Winglets ============================================ #

root.update();
start_btn = tk.Button(root, text = "Start", font = ('calbiri',12),command=plot_start)
start_btn.place(x = 20, y = 370 )

root.update();
stop_btn = tk.Button(root, text = "Stop", font = ('calbiri',12),command=plot_start)
stop_btn.place(x = start_btn.winfo_x()+start_btn.winfo_reqwidth() + 20, y = 370)

root.update();
reset_btn = tk.Button(root, text = "Reset", font = ('calbiri',12),command=plot_start)
reset_btn.place(x = stop_btn.winfo_x()+stop_btn.winfo_reqwidth() + 20, y = 370)


# ============================= Fourth row of Winglets ============================================ #

root.update();
start_btn = tk.Button(root, text = "Start", font = ('calbiri',12),command=plot_start)
start_btn.place(x = 20, y = 320 )

root.update();
stop_btn = tk.Button(root, text = "Stop", font = ('calbiri',12),command=plot_start)
stop_btn.place(x = start_btn.winfo_x()+start_btn.winfo_reqwidth() + 20, y = 320)

root.update();
reset_btn = tk.Button(root, text = "Reset", font = ('calbiri',12),command=plot_start)
reset_btn.place(x = stop_btn.winfo_x()+stop_btn.winfo_reqwidth() + 20, y = 320)


# ============================= Fifth row of Winglets ============================================ #

root.update();
start_btn = tk.Button(root, text = "Start", font = ('calbiri',12),command=plot_start)
start_btn.place(x = 20, y = 270 )

root.update();
stop_btn = tk.Button(root, text = "Stop", font = ('calbiri',12),command=plot_start)
stop_btn.place(x = start_btn.winfo_x()+start_btn.winfo_reqwidth() + 20, y = 270)

root.update();
reset_btn = tk.Button(root, text = "Reset", font = ('calbiri',12),command=plot_start)
reset_btn.place(x = stop_btn.winfo_x()+stop_btn.winfo_reqwidth() + 20, y = 270)


# ============================= Sixth row of Winglets ============================================ #

root.update();
start_btn = tk.Button(root, text = "Start", font = ('calbiri',12),command=plot_start)
start_btn.place(x = 20, y = 220 )

root.update();
stop_btn = tk.Button(root, text = "Stop", font = ('calbiri',12),command=plot_start)
stop_btn.place(x = start_btn.winfo_x()+start_btn.winfo_reqwidth() + 20, y = 220)

root.update();
reset_btn = tk.Button(root, text = "Reset", font = ('calbiri',12),command=plot_start)
reset_btn.place(x = stop_btn.winfo_x()+stop_btn.winfo_reqwidth() + 20, y = 220)

# ============================= Seventh row of Winglets ============================================ #

root.update();
start_btn = tk.Button(root, text = "Start", font = ('calbiri',12),command=plot_start)
start_btn.place(x = 20, y = 170 )

root.update();
stop_btn = tk.Button(root, text = "Stop", font = ('calbiri',12),command=plot_start)
stop_btn.place(x = start_btn.winfo_x()+start_btn.winfo_reqwidth() + 20, y = 170)

root.update();
reset_btn = tk.Button(root, text = "Reset", font = ('calbiri',12),command=plot_start)
reset_btn.place(x = stop_btn.winfo_x()+stop_btn.winfo_reqwidth() + 20, y = 170)

# ============================= Eighth row of Winglets ============================================ #

root.update();
start_btn = tk.Button(root, text = "Start", font = ('calbiri',12),command=plot_start)
start_btn.place(x = 20, y = 120 )

root.update();
stop_btn = tk.Button(root, text = "Stop", font = ('calbiri',12),command=plot_start)
stop_btn.place(x = start_btn.winfo_x()+start_btn.winfo_reqwidth() + 20, y = 120)

root.update();
reset_btn = tk.Button(root, text = "Reset", font = ('calbiri',12),command=plot_start)
reset_btn.place(x = stop_btn.winfo_x()+stop_btn.winfo_reqwidth() + 20, y = 120)

# ============================= Sixth row of Winglets ============================================ #

root.update();
start_btn = tk.Button(root, text = "Start", font = ('calbiri',12),command=plot_start)
start_btn.place(x = 20, y = 70 )

root.update();
stop_btn = tk.Button(root, text = "Stop", font = ('calbiri',12),command=plot_start)
stop_btn.place(x = start_btn.winfo_x()+start_btn.winfo_reqwidth() + 20, y = 70)

root.update();
reset_btn = tk.Button(root, text = "Reset", font = ('calbiri',12),command=plot_start)
reset_btn.place(x = stop_btn.winfo_x()+stop_btn.winfo_reqwidth() + 20, y = 70)

# ============================= Sixth row of Winglets ============================================ #

root.update();
start_btn = tk.Button(root, text = "Start", font = ('calbiri',12),command=plot_start)
start_btn.place(x = 20, y = 20 )

root.update();
stop_btn = tk.Button(root, text = "Stop", font = ('calbiri',12),command=plot_start)
stop_btn.place(x = start_btn.winfo_x()+start_btn.winfo_reqwidth() + 20, y = 20)

root.update();
reset_btn = tk.Button(root, text = "Reset", font = ('calbiri',12),command=plot_start)
reset_btn.place(x = stop_btn.winfo_x()+stop_btn.winfo_reqwidth() + 20, y = 20)

# =============================== Clossing ========================================== #

root.mainloop()

# %%
###############################################################################################
#
#                            Test of Sketchy development of Tachometer Interface
#
###############################################################################################

import tkinter as tk
import math
import time

# ========================= Main windown settings ============================= #

root = tk.Tk()
root.title('Buttoms distribution tester')
root.configure(background = '#e0e0e0')
root.iconbitmap('C:/Users/ASUS/Pictures/Logos/generic-logo.ico')
root.geometry("520x520") # set the window size


class Point:
    def __init__(self, x=0, y=0):
        self.x = x
        self.y = y


class TachoMeter(tk.Tk):
    def __init__(self, CenterPoint=Point(), LeftPoint=Point(), Radius=0, LeftBuffer=0, BottomBuffer=0, MIN_RPM=0,
                 MAX_RPM=0, canvas_height=0, canvas_width=0, *arg, **kwargs):
        tk.Tk.__init__(self, *arg, **kwargs)
        self.canvas = tk.Canvas(width=canvas_width, height=canvas_height)
        self.canvas.pack(fill="both", expand=True)
        self.CenterPoint = CenterPoint
        self.MAX_RPM = MAX_RPM
        self.MIN_RPM = MIN_RPM
        self.LeftBuffer = LeftBuffer
        self.BottomBuffer = BottomBuffer
        self.Radius = Radius
        self.Point_0 = LeftPoint
        self._create_arc((LeftPoint.x, LeftPoint.y), (LeftPoint.x + 2 * Radius, LeftPoint.y))
        self._rpmGauge()

    def _create_arc(self, p0, p1):
        extend_x = (self._distance(p0, p1) - (p1[0] - p0[0])) / 2
        extend_y = (self._distance(p0, p1) - (p1[1] - p0[1])) / 2
        startAngle = math.atan2(p0[0] - p1[0], p0[1] - p1[1]) * 180 / math.pi
        self.canvas.create_arc(p0[0] - extend_x, p0[1] - extend_y, p1[0] + extend_x, p1[1] + extend_y, extent=180,
                               start=90 + startAngle)
        self.canvas.create_arc(LeftPoint.x + Radius, LeftPoint.y, LeftPoint.x + Radius, LeftPoint.y - Radius)

    def _distance(self, p0, p1):
        return math.sqrt((p0[0] - p1[0]) ** 2 + (p0[1] - p1[1]) ** 2)

    def _rpmGauge(self):
        for x in range(180, 0, -1):
            curTheta = float((math.pi * x) / 180)
            curX = self.CenterPoint.x + (self.Radius * math.cos(curTheta))
            curY = self.CenterPoint.y - (self.Radius * math.sin(curTheta))
            self.line = self.canvas.create_line(self.CenterPoint.x, self.CenterPoint.y, int(curX), int(curY))
            self.canvas.pack()

            
Radius = 400
acanvas_width = 500
acanvas_height = 600
LeftBuffer = 100
BottomBuffer = 100
CenterPoint = Point(LeftBuffer + Radius, acanvas_height - BottomBuffer)
LeftPoint = Point(LeftBuffer, acanvas_height - BottomBuffer)
MAX_RPM = 8000
MIN_RPM = 0

root = TachoMeter(CenterPoint, LeftPoint, Radius, LeftBuffer, BottomBuffer, MIN_RPM, MAX_RPM, acanvas_height,acanvas_width)


root.mainloop()

# %%
###############################################################################################
#
#                                   Test of Slider (Horizontal)
#
###############################################################################################

import tkinter as tk
from tkinter import ttk


# root window
root = tk.Tk()
root.resizable(False, False)
root.title('GUI Slider Test')
root.configure(background = '#e0e0e0')
root.iconbitmap('C:/Users/ASUS/Pictures/Logos/generic-logo.ico')
root.geometry("390x70") # set the window size
#root.columnconfigure(0, weight=1)
#root.columnconfigure(1, weight=3)


# slider current value
current_value = tk.DoubleVar()

def get_current_value():
    return '{: .2f}'.format(current_value.get())

def slider_changed(event):
    value_label.configure(text=get_current_value())

# label for the slider

slider_label = ttk.Label(root, text='Slider:')
slider_label.place(x = 20, y = 10)

#  slider

slider = ttk.Scale(root,from_=0,to=100,orient='horizontal', command=slider_changed, variable=current_value,length=300)
slider.place(x = 70, y = 10)

# current value label

current_value_label = ttk.Label(root, text='Current Value:')
current_value_label.place(x = 100, y = 40)

# value label

value_label = ttk.Label(root,text=get_current_value())
value_label.place(x = current_value_label.winfo_x()+current_value_label.winfo_reqwidth() + 100, y = 40)

root.mainloop()

# %%
###############################################################################################
#
#                                   Test of Slider (Vertical)
#
###############################################################################################

import tkinter as tk
from tkinter import ttk


# root window
root = tk.Tk()
root.resizable(False, False)
root.title('GUI Slider Test')
root.configure(background = '#e0e0e0')
root.iconbitmap('C:/Users/ASUS/Pictures/Logos/generic-logo.ico')
root.geometry("250x360") # set the window size
#root.columnconfigure(0, weight=1)
#root.columnconfigure(1, weight=3)


# slider current value
current_value = tk.DoubleVar()

def get_current_value():
    return '{: .2f}'.format(current_value.get())

def slider_changed(event):
    value_label.configure(text=get_current_value())

# label for the slider

slider_label = ttk.Label(root, text='Slider:',font=("Arial Bold", 18))
slider_label.place(x = 120, y = 10)

#  slider

slider = ttk.Scale(root,from_=0,to=100,orient='vertical', command=slider_changed, variable=current_value,length=300)
slider.place(x = 70, y = 10)

# current value label

current_value_label = ttk.Label(root, text='Current Value:',font=("Arial Bold", 18))
current_value_label.place(x = 5, y = 330)



# value label

value_label = ttk.Label(root,text=get_current_value(),font=("Arial Bold", 18))
value_label.place(x = current_value_label.winfo_x()+current_value_label.winfo_reqwidth() + 5, y = 330)

root.mainloop()

# %%
###########################################################################################################
#
#                                      Gauge essential  
#
###########################################################################################################

import tkinter as tk
import tk_tools # reqiores pip install tk_tools

root = tk.Tk()
root.title('GUI Gauge Test')
root.iconbitmap('C:/Users/ASUS/Pictures/Logos/generic-logo.ico')
root.geometry("250x180") # set the window size


p = tk_tools.RotaryScale(root, max_value=100.0, unit='   psi')
p.place(x = 70, y = 20 )


p.set_value(44.44)

root.mainloop()

# %%
###########################################################################################################
#
#                                      Gauge with vanish effect   
#
###########################################################################################################

import tkinter as tk
from math import pi, cos, sin

root = tk.Tk()
root.title('GUI Slider Test')
root.configure(background = '#e0e0e0')
root.iconbitmap('C:/Users/ASUS/Pictures/Logos/generic-logo.ico')
root.geometry("260x180") # set the window size
#root.columnconfigure(0, weight=1)
#root.columnconfigure(1, weight=3)


class Meter(tk.Frame):
    def __init__(self, master=None, **kw):
        tk.Frame.__init__(self, master, **kw)

        self.meter = []
        self.angle = []
        self.var = tk.IntVar(self, 0)

        self.canvas = tk.Canvas(self, width=200, height=110,
                                borderwidth=2, relief='sunken',
                                bg='white')
        self.scale = tk.Scale(self, orient='horizontal', from_=0, to=100, variable=self.var)

        for j, i in enumerate(range(0, 100, 5)):
            self.meter.append(self.canvas.create_line(100, 100, 10, 100,
                                                      fill='grey%i' % i,
                                                      width=3,
                                                      arrow='last'))
            self.angle.append(0)
            self.canvas.lower(self.meter[j])
            self.updateMeterLine(0.2, j)

        self.canvas.create_arc(10, 10, 190, 190, extent=108, start=36,
                               style='arc', outline='red')

        self.canvas.pack(fill='both')
        self.scale.pack()

        self.var.trace_add('write', self.updateMeter)  # if this line raises an error, change it to the old way of adding a trace: self.var.trace('w', self.updateMeter)
        self.updateMeterTimer()

    def updateMeterLine(self, a, l=0):
        """Draw a meter line (and recurse for lighter ones...)"""
        oldangle = self.angle[l]
        self.angle[l] = a
        x = 100 - 90 * cos(a * pi)
        y = 100 - 90 * sin(a * pi)
        self.canvas.coords(self.meter[l], 100, 100, x, y)
        l += 1
        if l < len(self.meter):
            self.updateMeterLine(oldangle, l)

    def updateMeter(self, name1, name2, op):
        """Convert variable to angle on trace"""
        mini = self.scale.cget('from')
        maxi = self.scale.cget('to')
        pos = (self.var.get() - mini) / (maxi - mini)
        self.updateMeterLine(pos * 0.6 + 0.2)

    def updateMeterTimer(self):
        """Fade over time"""
        self.var.set(self.var.get())
        self.after(20, self.updateMeterTimer)


if __name__ == '__main__':
#    root = tk.Tk()
    meter = Meter(root)
    meter.pack()
    root.mainloop()

# %%
###########################################################################################################
#
#                                      Gauge simple  
#
###########################################################################################################

import tkinter as tk
from math import pi, cos, sin

root = tk.Tk()
root.title('GUI Slider Test')
root.configure(background = '#e0e0e0')
root.iconbitmap('C:/Users/ASUS/Pictures/Logos/generic-logo.ico')
root.geometry("260x180") # set the window size
#root.columnconfigure(0, weight=1)
#root.columnconfigure(1, weight=3)

class Meter(tk.Frame):
    def __init__(self, master=None, **kw):
        tk.Frame.__init__(self, master, **kw)

        self.var = tk.IntVar(self, 0)

        self.canvas = tk.Canvas(self, width=200, height=110,
                                borderwidth=2, relief='sunken',
                                bg='white')
        self.scale = tk.Scale(self, orient='horizontal', from_=0, to=100, variable=self.var)

        self.meter = self.canvas.create_line(100, 100, 10, 100,
                                             fill='black',
                                             width=3,
                                             arrow='last')
        self.angle = 0
        self.updateMeterLine(0.2)

        self.canvas.create_arc(10, 10, 190, 190, extent=108, start=36,
                               style='arc', outline='red')

        self.canvas.pack(fill='both')
        self.scale.pack()

        self.var.trace_add('write', self.updateMeter)  # if this line raises an error, change it to the old way of adding a trace: self.var.trace('w', self.updateMeter)

    def updateMeterLine(self, a):
        """Draw a meter line"""
        self.angle = a
        x = 100 - 90 * cos(a * pi)
        y = 100 - 90 * sin(a * pi)
        self.canvas.coords(self.meter, 100, 100, x, y)

    def updateMeter(self, name1, name2, op):
        """Convert variable to angle on trace"""
        mini = self.scale.cget('from')
        maxi = self.scale.cget('to')
        pos = (self.var.get() - mini) / (maxi - mini)
        self.updateMeterLine(pos * 0.6 + 0.2)

if __name__ == '__main__':
#    root = tk.Tk()
    meter = Meter(root)
    meter.pack()
    root.mainloop()

# %%
###########################################################################################################
#
#                                      Light Sign sequence   
#
###########################################################################################################


import tkinter as tk
import time

arr = [5, 6, 7, 8, 3, 2, 4, 9]  # Set the list of numbers


def start_indicators():
    """
    This function updates the widgets based on your list
    :return: None
    """

    for x in arr:  # Iterate through the list.
        label_text = "Current value: {}".format(x)  # Set the text of Label
        if x < 3:
            print("Value: {} - Danger!".format(x))
            my_canvas.itemconfig(my_oval, fill="red")  # Fill the circle with RED
            label_var.set(label_text)  # Updating the label
        elif 3 < x < 7:
            print("Value: {} - Warning!".format(x))
            my_canvas.itemconfig(my_oval, fill="yellow")  # Fill the circle with YELLOW
            label_var.set(label_text)  # Updating the label
        elif x > 7:
            print("Value: {} - Safe!".format(x))
            my_canvas.itemconfig(my_oval, fill="green")  # Fill the circle with GREED
            label_var.set(label_text)  # Updating the label
        root.update()  # Update the complete GUI.
        time.sleep(2)  # Sleep two secs
    print("FINISH")


root = tk.Tk()  # Set Tk instance
root.iconbitmap('C:/Users/ASUS/Pictures/Logos/generic-logo.ico')
root.title('Test of warning lights (basic)')
root.geometry("330x280") # set the window size

my_canvas = tk.Canvas(root, width=200, height=200)  # Create 200x200 Canvas widget
my_canvas.pack()

my_oval = my_canvas.create_oval(50, 50, 100, 100)  # Create a circle on the Canvas

label_var = tk.StringVar()  # Set the string variable for Label widget

my_label = tk.Label(root, textvariable=label_var)  # Set the LAbel widget
my_label.pack()

my_button = tk.Button(root, text="START", command=start_indicators)  # Set a "Start button". The "start_indicators" function is a call-back.
my_button.pack()

root.mainloop()

# %%
###########################################################################################################
#
#                                        Light Sign test
#
###########################################################################################################

import tkinter as tk
import tk_tools # reqiores pip install tk_tools

root = tk.Tk()
root.title('Test of warning lights')
root.configure(background = '#e0e0e0')
root.iconbitmap('C:/Users/ASUS/Pictures/Logos/generic-logo.ico')
root.geometry("300x120") # set the window size
#root.columnconfigure(0, weight=1)
#root.columnconfigure(1, weight=3)

       ########################### Functions set ###########################

def turn_LED_ON():
    led.to_green(on=True)
    
def turn_LED_RED():
    led.to_red(on=True)
    
def turn_LED_YELLOW():
    led.to_yellow(on=True)
    
def turn_LED_OFF():
    led.to_grey(on=True)

        ###########################Buttons Widget###########################

root.update();
start_btn = tk.Button(root, text = "Start", font = ('calbiri',12),command=turn_LED_ON, height= 1, width=7)
start_btn.place(x = 20, y = 20 )

root.update();
stop_btn = tk.Button(root, text = "Warning", font = ('calbiri',12),command=turn_LED_RED, height= 1, width=7)
stop_btn.place(x = start_btn.winfo_x()+start_btn.winfo_reqwidth() + 20, y = 20)

root.update();
start_btn = tk.Button(root, text = "Stand by", font = ('calbiri',12),command=turn_LED_YELLOW, height= 1, width=7)
start_btn.place(x = 20, y = 60 )

root.update();
stop_btn = tk.Button(root, text = "Off", font = ('calbiri',12),command=turn_LED_OFF, height= 1, width=7)
stop_btn.place(x = start_btn.winfo_x()+start_btn.winfo_reqwidth() + 20, y = 60)

led = tk_tools.Led(root, size=50)
led.place(x = stop_btn.winfo_x()+stop_btn.winfo_reqwidth() + 140, y = 20 )

root.mainloop()

# %%
#####################################################################################################################################
#####################################################################################################################################
##
##                                                      Dial knob
##
#####################################################################################################################################
#####################################################################################################################################

import tkinter as tk
from tkinter import ttk

from PIL import Image, ImageTk, ImageDraw

class Gauge(ttk.Label):

    def __init__(self, parent, **kwargs):
        self.arc = None
        self.im = Image.new('RGBA', (1000, 1000))
        self.min_value = kwargs.get('minvalue') or 0
        self.max_value = kwargs.get('maxvalue') or 100
        self.size = kwargs.get('size') or 200
        self.font = kwargs.get('font') or 'helvetica 12 bold'
        self.background = kwargs.get('background')
        self.foreground = kwargs.get('foreground') or '#777'
        self.troughcolor = kwargs.get('troughcolor') or '#e0e0e0'
        self.indicatorcolor = kwargs.get('indicatorcolor') or '#01bdae'
        self.arcvariable = tk.IntVar(value='text')
        self.arcvariable.trace_add('write', self.update_arcvariable)
        self.textvariable = tk.StringVar()
        self.setup()

        super().__init__(parent, image=self.arc, compound='center', style='Gauge.TLabel',
                         textvariable=self.textvariable, **kwargs)

    def setup(self):
        """Setup routine"""
        style = ttk.Style()
        style.configure('Gauge.TLabel', font=self.font, foreground=self.foreground)
        if self.background:
            style.configure('Gauge.TLabel', background=self.background)
        draw = ImageDraw.Draw(self.im)
        draw.arc((0, 0, 990, 990), 0, 360, self.troughcolor, 100)
        self.arc = ImageTk.PhotoImage(self.im.resize((self.size, self.size), Image.LANCZOS))

    def update_arcvariable(self, *args):
        """Redraw the arc image based on variable settings"""
        angle = int(float(self.arcvariable.get())) + 90
        self.im = Image.new('RGBA', (1000, 1000))
        draw = ImageDraw.Draw(self.im)
        draw.arc((0, 0, 990, 990), 0, 360, self.troughcolor, 100)
        draw.arc((0, 0, 990, 990), 90, angle, self.indicatorcolor, 100)
        self.arc = ImageTk.PhotoImage(self.im.resize((self.size, self.size), Image.LANCZOS))
        self.configure(image=self.arc)


if __name__ == '__main__':
    root = tk.Tk()
    style = ttk.Style()
    gauge = Gauge(root, padding=20)
    gauge.pack()
    ttk.Scale(root, from_=0, to=360, variable=gauge.arcvariable).pack(fill='x', padx=10, pady=10)
    root.title('Test of dial knob')
    root.configure(background = '#e0e0e0')
    root.iconbitmap('C:/Users/ASUS/Pictures/Logos/generic-logo.ico')
    root.geometry("300x300") # set the window size
    
    # update the textvariable with the degrees information when the arcvariable changes
    gauge.arcvariable.trace_add('write', lambda *args, g=gauge: g.textvariable.set(f'{g.arcvariable.get()} deg'))

    root.mainloop()

# %%
#####################################################################################################################################
#####################################################################################################################################
##
##                                                      Dial knob advanced
##
#####################################################################################################################################
#####################################################################################################################################

import tkinter as tk
from tkinter import ttk
from PIL import Image, ImageTk, ImageDraw
from tkinter import StringVar, IntVar
from tkinter.ttk import Frame
from ttkbootstrap import Style, Colors

from PIL import Image, ImageTk, ImageDraw
from ttkbootstrap import Style # pip install ttkbootstrap


class RadialGauge(ttk.Label):
    """
    A RadialGauge widget shows the amount completed relative to the total amount of work to be done.

    :param str background: use this option to set the background color. You may also use the ``style``.
    :param str cursor: use this option to specify the appearance of the mouse cursor when it is over the widget.
    :param str font: use this option to specify the font style for the displayed text. You man also use the ``style``.
    :param str foreground: use this option to specify the color of the displayed text. You may also use the ``style``.
    :param str indicator color: use this option to specify the indicator color. Default is style foreground color.
    :param str justify: if the text you provide contains newline ``\n`` characters, this option specifies how each line
        will be positioned horizontally: **left**, **center**, **right**. You may also use the ``style``.
    :param Union[Iterable[int], int] maximum: the maximum value of the indicator; default is 100.
    :param any padding: to add more space around all four sides of the gauge, set this option to the desired dimension.
        You may also use the ``style``.
    :param str style: the style to be used in rendering the widget.
    :param object styler: an instance of ``Style``. If not provided, it will be created and the default application
        theme will be used.
    :param str theme: the name of theme to use when styling the widget. Use any of the `TLabel` style classes.
    :param bool takefocus: use this option to specify whether the widget is visited during focus traversal.
    :param str text: a string of text to be displayed in the widget.
    :param object textvariable: a ``StringVar`` instance; get and set the text displayed in the widget; if a ``text``
        option is used, then ``text`` will be ignored. If not provided, it will be created and can be accessed via the
        ``textvariable`` property.
    :param str troughcolor: use this option to set the color of the trough: Default is theme border color.
    :param int underline: You can request that one of the letters in the text string be underlined by setting this
        option to the position of that letter.
    :param int value: the current value of the progressbar. If the variable is set to an existing value, this has no
        effect.
    :param object variable: an ``IntVar`` instance; get and set the current value of the indicator. If a variable is
        not provided, one will be created and can be accessed via the ``variable`` property``.

    ..note:: Because this is not strictly a `ttk` widget, you need to pass in a reference to a ``Style`` instance with
        the ``styler`` argument so that the widget knows what theme to extract the colors values from. If not provided,
        one will be created with the default application theme `flatly`.
    """

    def __init__(self, parent, styler=None, style='primary.TLabel', **kwargs):

        excluded = ['anchor', 'theme', 'image', 'compound', 'relief', 'bordwidth', 'maximum', 'value', 'variable','minimum', 
                    'indicatorcolor', 'troughcolor', 'textvariable']
        kwargs_ = {k: v for k, v in kwargs.items() if k not in excluded}
        super().__init__(parent, class_='RadialGauge', style=style, **kwargs_)

        self.styler = Style() if not styler else styler
        self.indicatorcolor = kwargs.get('indicatorcolor') or self.styler.lookup(style, 'foreground')
        self.troughcolor = kwargs.get('troughcolor') or self.styler.lookup('Horizontal.TProgressbar', 'troughcolor')
        self.is_maximum = False  # used to control the forward and reverse on the ``step`` method
        self.is_minimum = False

        # variable controls
        self.textvariable = kwargs.get('textvariable') or tk.StringVar(value=kwargs.get('text'))
        self.configure(textvariable=self.textvariable)
        self.variable = kwargs.get('variable') or tk.IntVar(value=kwargs.get('value'))
        self.variable.trace_add('write', self.update_indicator)
        self.maximum = 100 if kwargs.get('maximum') == None or kwargs.get('maximum') <= 0 else kwargs.get('maximum')
        self.minimum = 0 if kwargs.get('minimum') == None or kwargs.get('minimum') <= 0 else kwargs.get('minimum')


        # create the image for drawing the arc trough and indicator
        self.arc = None
        self.size = kwargs.get('size') or 100  # the eventual size of the widget
        self.im = Image.new('RGBA', (1000, 1000))  # create large and then subsample for higher quality image
        draw = ImageDraw.Draw(self.im)
        draw.arc((0, 0, 990, 990), 0, 360, self.troughcolor, 100)
        self.arc = ImageTk.PhotoImage(self.im.resize((self.size, self.size), Image.CUBIC))

        self.configure(compound='center', anchor='center', image=self.arc)
        self.bind('<Configure>', self.resize)

    def resize(self, event):
        """
        This is a callback for the widget's <Configure>. This method enables the widget to shrink and grow when resized
        and if permitted by the `pack`, `grid`, or `place` geometry managers.

        :param event: the <Configure> event that is triggered when the gauge widget is resized.
        """
        padding = 4  # not sure why this is required, but if I don't include it it growths continually
        self.size = max(min(event.width - padding, event.height - padding), 100)
        self.update_indicator()

    def step(self, delta=1):
        """
        Increase the indicator value by ``delta``. The default increment is one unit. The indicator will reverse direction and
        count down once it reaches the maximum value.

        :param delta: the amount to change the indicator.
        """
        var = float(self.variable.get())
        if var >= float(self.maximum):
            self.is_maximum = True
            self.variable.set(var - delta)
        elif var <= 0:
            self.is_maximum = False
            self.variable.set(var + delta)
        elif self.is_maximum:
            self.variable.set(var - delta)
        else:
            self.variable.set(var + delta)
            
    def down(self, delta=1):
        """
        Decrease the indicator value by ``delta``. The default decrease is one unit. The indicator will reverse direction and
        count up once it reaches the minimum value.

        :param delta: the amount to change the indicator.
        """
        var = float(self.variable.get())
        if var >= float(self.minimum):
            self.is_maximum = False
            self.variable.set(var - delta)
        elif var >= 0:
            self.is_maximum = True
            self.variable.set(var - delta)
        elif self.is_maximum:
            self.variable.set(var - delta)
        else:
            self.variable.set(var + delta)

    def update_indicator(self, *args):
        """
        Redraw the arc image based on the ``variable`` value.

        If invoked by a trace, the *args include: variable_name, array_index, mode. See ``tkinter.trace_add``
        for more information on this functionality. https://docs.oracle.com/cd/E88353_01/html/E37839/trace-1t.html

        """
        var = float(self.variable.get()) / self.maximum
        angle = 450 if var >= 1.0 else (int(var * 360) + 90)
        self.im = Image.new('RGBA', (1000, 1000))
        draw = ImageDraw.Draw(self.im)
        draw.arc((0, 0, 990, 990), 0, 360, self.troughcolor, 100)
        draw.arc((0, 0, 990, 990), 90, angle, self.indicatorcolor, 100)
        self.arc = ImageTk.PhotoImage(self.im.resize((self.size, self.size), Image.CUBIC))
        self.configure(image=self.arc)


if __name__ == '__main__':
    # Create the main window
    root = tk.Tk()
    root.geometry('400x400')
    style = Style('cosmo')
    root.title('Test of dial knob')
    root.configure(background = '#e0e0e0')
    root.iconbitmap('C:/Users/ASUS/Pictures/Logos/generic-logo.ico')    

    # Create the gauge widget
    gauge = RadialGauge(root, styler=style, font='helvetica 14 bold', maximum=360, value=10, text='10 rpm')
    gauge.pack(fill='both', expand='yes', padx=5, pady=20)
    gauge.variable.trace_add('write', lambda *args, g=gauge: g.textvariable.set(f'{g.variable.get()} rpm'))

    # Setup some indicator controls
    ttk.Scale(root, from_=0, to=360, variable=gauge.variable).pack(fill='x', padx=10, pady=10)
   
    ttk.Button(root, text='Increment the rpm', command=gauge.step).pack(padx=10, pady=10, fill='x')
    
    ttk.Button(root, text='Decrease the rpm', command=gauge.down).pack(padx=10, pady=10, fill='x')

    root.mainloop()

# %%
#######################################################################################################################
#
#                                            Light to Dark mode Swtich: Early early stage
#
#######################################################################################################################

from tkinter import *
  
window = Tk()
window.title("Theme Switch test")  
window.geometry("700x350")
window.config(bg="white")
window.iconbitmap('C:/Users/ASUS/Pictures/Logos/generic-logo.ico')   
  
  
#Adding light and dark mode images

light = PhotoImage(file="C:/Users/ASUS/Pictures/Light_mode.png")
dark = PhotoImage(file="C:/Users/ASUS/Pictures/Dark_mode.png")
  
switch_value = True
  
# Defining a function to toggle
# between light and dark theme

def toggle():
  
    global switch_value
    
    if switch_value == True:
        switch.config(image=dark, bg="black",
                      activebackground="black") # originally "#26242f" and also worked good with "blue", it defines the buttom border color
          
        # Changes the window to dark theme
        window.config(bg="black")  # originally #26242f
        switch_value = False
  
    else:
        switch.config(image=light, bg="white", 
                      activebackground="white")
          
        # Changes the window to light theme
        window.config(bg="white")  
        switch_value = True
  
  
# Creating a button to toggle
# between light and dark themes

switch = Button(window, image=light, 
                bd=0, bg="white",
                activebackground="white", 
                command=toggle)
switch.pack(padx=10, pady=50) # define the margins size
  
window.mainloop()

# %%
#######################################################################################################################
#
#                                            Print in the screen the current date and time
#
#######################################################################################################################

# Import the libraries
from tkinter import *
import datetime as dt

# Config the windows

root = Tk()
root.title("Display Current Date")  
root.geometry("400x150")
#root.config(bg="white")
root.iconbitmap('C:/Users/ASUS/Pictures/Logos/generic-logo.ico')  

date = dt.datetime.now()
# Create Label to display the Date
label = Label(root, text=f"{date:%A, %B %d, %Y}", font="Calibri, 18")
label.pack(pady=20)

root.mainloop()

# %%
#######################################################################################################################
#
#                                            Generate short file with the date
#
#######################################################################################################################

# Import the libraries
from tkinter import *
import datetime as dt

# Config the windows

root = Tk()
root.title("Display Current Date")  
root.geometry("400x150")
#root.config(bg="white")
root.iconbitmap('C:/Users/ASUS/Pictures/Logos/generic-logo.ico')  

date = dt.datetime.now()
# Create Label to display the Date
label = Label(root, text=f"{date:%A, %B %d, %Y}", font="Calibri, 18")
label.pack(pady=20)

def print_report():
    f = open("C:/Users/ASUS/Desktop/GeneratedReport.txt", "w")
    f.write("Report\n\n")
    f.write("Date: {}\n".format(date)) 
    
btn_report = Button(root, text="Print date", width=15, height =2, font=('arial',18,'bold'), bd=7, bg='gainsboro', command=print_report)
btn_report.place(x = 70, y = 55 )

root.mainloop()

# %%
##################################################################################
#
#
#                               Reloj en pantalla
#
#
##################################################################################

# importing whole module
from tkinter import * 
from tkinter.ttk import *
  
# importing strftime function to
# retrieve system's time
from time import strftime
  
# creating tkinter window
root = Tk()
root.title("Display Current Time")  
root.iconbitmap('C:/Users/ASUS/Pictures/Logos/generic-logo.ico')  
root.resizable(width=False, height=False)
root.geometry("370x75+650+40")
  
# This function is used to 
# display time on the label
def time():
    string = strftime('%H:%M:%S %p')
    lbl.config(text = string)
    lbl.after(1000, time)
  
# Styling the label widget so that clock
# Define the final style of the watch

lbl = Label(root, font = ('courier', 40, 'bold'),
            background = 'black',
            foreground = 'lime')
  
# Placing clock at the centre
# of the tkinter window
lbl.pack(anchor = 'center')
time()
  
mainloop()

# %%
# Status: under development with errors and not functional
###############################################################################################
#
#                                   Test of Slider (Vertical) Updated with Style
#
###############################################################################################

import tkinter as tk
from tkinter import ttk
from tkinter import * 
from tkinter.ttk import *
import tk_tools # reqiores pip install tk_tools

# root window
root = tk.Tk()
root.resizable(False, False)
root.title('GUI Slider Test')
root.configure(background = '#e0e0e0')
root.iconbitmap('C:/Users/ASUS/Pictures/Logos/generic-logo.ico')
root.geometry("450x100") # set the window size
#root.columnconfigure(0, weight=1)
#root.columnconfigure(1, weight=3)


# slider current value
current_value = tk.IntVar() # originally DoubleVar() 

       ########################### Interface set ##########################

slider_label = ttk.Label(root, text='Slider:',font=("Arial Bold", 14),background = '#e0e0e0')
slider_label.place(x = 120, y = 10)

led = tk_tools.Led(root, size=50)
led.place(x =  370, y = 20 )

current_value_label = ttk.Label(root, text='Current Value:',font=("courier", 14, 'bold'),background = 'black',foreground = 'lime')
current_value_label.place(x = 90, y = 60)

       ########################### Functions set ##########################

    
def get_current_value():
    return '{: .2f}'.format(current_value.get(),font=("courier", 14, 'bold'),background = 'black',foreground = 'lime')
    
def slider_changed(event):

    # value label

    value_label = ttk.Label(root,text=get_current_value(),font=("courier", 14, 'bold'),background = 'black',foreground = 'lime')
    value_label.place(x = current_value_label.winfo_x()+current_value_label.winfo_reqwidth() + 5, y = 60)

    value_label.configure(text=get_current_value())
    led = tk_tools.Led(root, size=50)
#
    
    if get_current_value() < 50:
        led.to_green(on=True)
    
    elif range(20, 59):
        led.to_red(on=True)
        
    elif range(60, 79):
        led.to_yellow(on=True)
  
    else:
         led.to_grey(on=True)

# On/Off 

slider = ttk.Scale(root,from_=0,to=100,orient='horizontal', command=slider_changed, variable=current_value,length=300)
slider.place(x = 50, y = 10)

root.update();
start_btn = tk.Button(root, text = "Start", font = ('calbiri',12),command=slider_changed)
start_btn.place(x = 20, y = 55 )

root.mainloop()
