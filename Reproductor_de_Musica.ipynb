# %%
##################################################################################
#
#
#                               Reproductor de Musica
#
#
##################################################################################

from tkinter import *

import time
from time import strftime 
from tkinter import * 
import datetime
from pygame import mixer # pip install pygame

root = Tk()
root.wm_iconbitmap('C:/Users/ASUS/Pictures/Logos/generic-logo.ico')
root.wm_title('Personal Music Mixer')
root.resizable(width=False, height=False)
root.geometry("540x400")

mainFrame = Frame(root, bd=10, bg='gainsboro',relief=RIDGE)
mainFrame.grid()

innerFrame = Frame(mainFrame, bd=5, bg='gainsboro', relief=RIDGE)
innerFrame.grid()


def setalarm():
    mixer.init()
    mixer.music.load(r'C:\Users\renea\Music\TFS_Music_for_work\Alarm.mp3')
    mixer.music.play()
    
def DeepHouse():
    mixer.init()
    mixer.music.load(r'C:\Users\renea\Music\TFS_Music_for_work\Mega Hits 2020.mp3')
    mixer.music.play()   
    
def setSalsa():
    mixer.init()
    mixer.music.load(r'C:\Users\renea\Music\TFS_Music_for_work\Dejame Sentirte_1080p.mp4')
    mixer.music.play()  
        
def stopalarm():
    mixer.music.stop()
    
def pausealarm():
    mixer.music.pause()
    
def unpausealarm():
    mixer.music.unpause()
        
def alarmclock(alarmtime): 
    while True:
        time.sleep(1)
        time_now=datetime.datetime.now().strftime("%H:%M:%S")
        print(time_now)
        if time_now==alarmtime:
            Wakeup=Label(root, font = ('arial', 20, 'bold'),
            text="Take a break",bg="DodgerBlue2",fg="white").grid(row=6,columnspan=3)
           #print("wake up!")
            mixer.init()
            mixer.music.load(r'C:\Users\renea\Desktop\Alarm.mp3')
            mixer.music.play()
            break


        #============================================Buttons Widget===============================================#

btnStart = Button(innerFrame, text="Start", width=10, height =2, font=('arial',18,'bold'), bd=7, bg='gainsboro', command=setalarm)
btnStart.grid(row=0,column = 0)

btnStart = Button(innerFrame, text="Salsa", width=10, height =2, font=('arial',18,'bold'), bd=7, bg='gainsboro', command=setSalsa)
btnStart.grid(row=0,column = 1)

btnStart = Button(innerFrame, text="Deep Hause", width=10, height =2, font=('arial',18,'bold'), bd=7, bg='gainsboro', command=DeepHouse)
btnStart.grid(row=1,column = 1)

btnStart = Button(innerFrame, text="Ballads", width=10, height =2, font=('arial',18,'bold'), bd=7, bg='gainsboro', command=DeepHouse)
btnStart.grid(row=2,column = 1)

btnStart = Button(innerFrame, text="Rock", width=10, height =2, font=('arial',18,'bold'), bd=7, bg='gainsboro', command=DeepHouse)
btnStart.grid(row=3,column = 1)

btnStop = Button(innerFrame, text="Stop", width=10, height =2, font=('arial',18,'bold'), bd=7, bg='gainsboro', command=stopalarm)
btnStop.grid(row=1,column = 0)

btnPause = Button(innerFrame, text="Pause", width=10, height =2, font=('arial',18,'bold'), bd=7, bg='gainsboro', command=pausealarm)
btnPause.grid(row=2,column = 0)

btnAgain = Button(innerFrame, text="Continue", width=10, height =2, font=('arial',18,'bold'), bd=7, bg='gainsboro', command=unpausealarm)
btnAgain.grid(row=3,column = 0)

root.mainloop()
